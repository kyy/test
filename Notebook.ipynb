# %%
from main import *
# %matplotlib inline

# %%
draw_plots(DATA, [['gt_corners', 'rb_corners'], ['min', 'max']])
# Out:
# 100%|██████████| 2/2 [00:00<00:00,  3.74it/s]
# ['plots/gt_corners_rb_corners.png', 'plots/min_max.png']
